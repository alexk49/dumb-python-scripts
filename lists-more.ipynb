# %% [markdown]
# ## advanced lists

# %%
l = [1,2,3]

# %% [markdown]
# add to end of list

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3]

# %% [markdown]
# Count how often something is in list:

# %%
l.count(10)
# Out:
# 0

# %%
l.count(4)
# Out:
# 1

# %% [markdown]
# .extend method

# %%
x = [1,2,3]
x.append([4,5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# append just adds element to the list

# %% [markdown]
# .extend will actually extend the list:

# %%
x = [1,2,3]
x.extend([4,5])
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3]

# %% [markdown]
# Index method returns the index value of whatever value is palced as the argument:

# %%
l.index(2)
# Out:
# 1

# %% [markdown]
# Will get ValueError if you try to index something not in the list

# %% [markdown]
# .insert() - this insert item into a list by the index value

# %%
l.insert(2,'inserted')

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %% [markdown]
# Index in first then object you want to insert

# %% [markdown]
# .pop() - takes off last element off list by default but can assign index

# %%
ele = l.pop()

# %%
ele
# Out:
# 3

# %%
l
# Out:
# [1, 2, 'inserted']

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 'inserted']

# %% [markdown]
# Remove method, pass in value you want to remove:

# %%
l.remove('inserted')

# %%
l
# Out:
# [2]

# %% [markdown]
# Note this will only remove the first instance of it

# %%
l = [1,2,3,4,5,62,2,2]

# %%
l.remove(2)

# %%
l
# Out:
# [1, 3, 4, 5, 62, 2, 2]

# %% [markdown]
# You can reverse list:

# %%
l.reverse()

# %%
l
# Out:
# [2, 2, 62, 5, 4, 3, 1]

# %% [markdown]
# .sort() will sort method in place value:

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 2, 3, 4, 5, 62]
