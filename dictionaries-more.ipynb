# %% [markdown]
# Many of the dictionary methods have been covered already

# %%
d = {'k1':1,'k2':2}

# %% [markdown]
# Dictionary comprehension:

# %%
{x:x**2 for x in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# Find keys that are not based on values:

# %%
{k:v**2 for k,v in zip(['a','b'],range(2))}
# Out:
# {'a': 0, 'b': 1}

# %% [markdown]
# ^ key names based on position in dictionary - not used very often

# %% [markdown]
# itermethods to loop through

# %%
for k in d.items():
    print(k)
# Out:
# ('k1', 1)
# ('k2', 2)

# %%
for k in d.keys():
    print(k)
# Out:
# k1
# k2

# %%
for k in d.values():
    print(k)
# Out:
# 1
# 2

# %%
d.items()
# Out:
# dict_items([('k1', 1), ('k2', 2)])

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
d.values()
# Out:
# dict_values([1, 2])
