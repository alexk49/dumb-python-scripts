# %%
2+2
# Out:
# 4

# %%
4/2
# Out:
# 2.0

# %%
7*4
# Out:
# 28

# %%
28/4
# Out:
# 7.0

# %%
7 / 4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2 + 10) * (10 + 3)
# Out:
# 156

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.1 - 0.3 + 0.1
# Out:
# -0.09999999999999998

# %%
my_dogs = 2

# %%
my_dogs = ["Sammy", "Frankie"]
