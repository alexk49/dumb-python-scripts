# %%
def myfunc(a,b,c=0):
    # Returns 5% of the sum of a and b
    return sum((a,b)) * 0.05

# %%
myfunc(40,60)
# Out:
# 5.0

# %%
def myfunc(*args):
    print(args)
    # Returns 5% of the sum of a and b
    return sum(args) * 0.05

# %%
myfunc(40,7,50,2,3,6,7,5,4,3)
# Out:
# (40, 7, 50, 2, 3, 6, 7, 5, 4, 3)
# 6.3500000000000005

# %%
def myfunc2(*args):
    for item in args:
        print(item)

# %%
myfunc2(40,60,100)
# Out:
# 40
# 60
# 100

# %%
def myfunc(**kwargs):
    if 'fruit' in kwargs:
        print('My fruit of choice is {}'.format(kwargs['fruit']))
    else:
        print('I did not find any fruit here')

# %%
myfunc(fruit='apple')
# Out:
# My fruit of choice is apple

# %%
myfunc(fruit='apple',veggie = 'lettuce')
# Out:
# My fruit of choice is apple

# %%
def myfunc(**kwargs):
    print(kwargs)
    if 'fruit' in kwargs:
        print('My fruit of choice is {}'.format(kwargs['veggie']))
    else:
        print('I did not find any fruit here')

# %%
myfunc(fruit='apple',veggie = 'lettuce')
# Out:
# {'fruit': 'apple', 'veggie': 'lettuce'}
# My fruit of choice is lettuce

# %%
def myfunc(*args,**kwargs):
    print(args)
    print(kwargs)
    print('I would like {} {}'.format(args[0],kwargs['food']))

# %%
myfunc(10,20,30,fruit='orange',food='eggs',animal='dog')
# Out:
# (10, 20, 30)
# {'fruit': 'orange', 'food': 'eggs', 'animal': 'dog'}
# I would like 10 eggs

# %%
def myfunc(*args):
    for nu%2 == 0:
        return num

# %%
myfunc(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14052/857995250.py in <module>
# ----> 1 myfunc(5,6,7,8)
#
# ~\AppData\Local\Temp/ipykernel_14052/1309742325.py in myfunc(*args)
#       1 def myfunc(*args):
# ----> 2     if num in args %2 == 0:
#       3         return num
#
# NameError: name 'num' is not defined

# %%
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14052/782157087.py in <module>
# ----> 1 print(mylist)
#
# NameError: name 'mylist' is not defined

# %%
string = 'alex'

# %%
string.upper()[0::2]
# Out:
# 'AE'

# %%
string.lower()[1::2]
# Out:
# 'lx'

# %%
string.join(string.upper()[0::2].string.lower()[1::2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14052/3441656357.py in <module>
# ----> 1 string.join(string.upper()[0::2].string.lower()[1::2])
#
# AttributeError: 'str' object has no attribute 'string'

# %%
def myfunc(string):
    out = []
    x=string.upper()[0::2]
    y=string.lower()[1::2]
    out = x+y
    print(out)

# %%
myfunc('Anthropomorphism')
# Out:
# ATRPMRHSnhooopim

# %%
def myfunc(x):
    out = []
    for i in range(len(x)):
        if i %2 == 0:
            out.append(x[i].lower())
        else:
            out.append(x[i].upper())
    return ''.join(out)

# %%
myfunc("Anthromophism")
# Out:
# 'aNtHrOmOpHiSm'

# %%
def myfunc(string):
    out = []
    for i in range(len(string)):
        if i%2==0:
            out.append(string[i].upper)
        else:
            out.append(string(i).lower)
    return ''.join(out)
