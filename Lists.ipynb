# %%
myList = [1,2,3]

# %%
myList
# Out:
# [1, 2, 3]

# %%
myList = ['STRING',100,23.2]

# %%
myList
# Out:
# ['STRING', 100, 23.2]

# %%
len(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2536/2292191500.py in <module>
# ----> 1 len(my_list)
#
# NameError: name 'my_list' is not defined

# %%
len(myList)
# Out:
# 3

# %%
mylist = ['one', 'two','three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
mylist
# Out:
# ['one', 'two', 'three']

# %%
another_list = ['four', 'five']

# %%
mylist + another_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
mylist
# Out:
# ['one', 'two', 'three']

# %%
newlist = mylist + another_list

# %%
newlist
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlist
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlist[0] = 'ONE'

# %%
newlist
# Out:
# ['ONE', 'two', 'three', 'four', 'five']

# %%
newlist.upper[1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2536/3059786876.py in <module>
# ----> 1 newlist.upper[1]
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
newlist[1].upper
# Out:
# <function str.upper()>

# %%
newlist
# Out:
# ['ONE', 'two', 'three', 'four', 'five']

# %%
newlist.append('six')

# %%
newlist.append('seven')

# %%
newlist.pop()
# Out:
# 'seven'

# %%
newlist
# Out:
# ['ONE', 'two', 'three', 'four', 'five', 'six']

# %%
popped_item = newlist.pop()

# %%
popped_item
# Out:
# 'six'

# %%
newlist
# Out:
# ['ONE', 'two', 'three', 'four', 'five']

# %%
newlist.pop(0)
# Out:
# 'ONE'

# %%
newlist
# Out:
# ['two', 'three', 'four', 'five']

# %%
new_list = ['a', 'e', 'x', 'b', 'c']

# %%
num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
new_list.sort()

# %%
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list
# Out:
# [4, 1, 8, 3]

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
newList = ['a', 'h', 'x', 't', 'hello',1,7,3,6,4]

# %%
newList
# Out:
# ['a', 'h', 'x', 't', 'hello', 1, 7, 3, 6, 4]

# %%
newList.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2536/3075955873.py in <module>
# ----> 1 newList.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
newList = ['a', 'h', 'x', 't', 'hello', '1', '7', '3', '6', '4']

# %%
newList.sort()

# %%
newList
# Out:
# ['1', '3', '4', '6', '7', 'a', 'h', 'hello', 't', 'x']

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]

# %%
mylist1 = [1,2,3]

# %%
mylist2 = [4,5,6]

# %%
mylist3 = [7,8,9]

# %%
matrix = [mylist1,mylist2,mylist3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[0][2]
# Out:
# 3

# %%
matrix[3][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9440/2928361367.py in <module>
# ----> 1 matrix[3][0]
#
# IndexError: list index out of range

# %%
matrix[2][0]
# Out:
# 7

# %%
# Python has an advanced feature called list comprehensions. They allow for quick construction of lists.

# %%
first_col = [row[0] for row in matrix]

# %%
first_c
