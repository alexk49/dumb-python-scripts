# %%
def paper_doll(text):
    myList = [l*3 for l in text]
    return ''.join(myList)

# %%
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
text = "test"
myList = [l*3 for l in text]

# %%
myList
# Out:
# ['ttt', 'eee', 'sss', 'ttt']

# %%
''.join(myList)
# Out:
# 'ttteeesssttt'

# %%
def summer_69(arr):
    for num in num in arr:

# %%
arr = ([1,2,3,6])

# %%
print(arr)
# Out:
# [1, 2, 3, 6]

# %%
arr[0:]
# Out:
# [1, 2, 3, 6]

# %%
arr[0:] == 6
# Out:
# False

# %%
range(arr)(0:2)
# Out:
#   File "C:\Users\Alex\AppData\Local\Temp/ipykernel_12736/2927475511.py", line 1
#     range(arr)(0:2)
#                 ^
# SyntaxError: invalid syntax
