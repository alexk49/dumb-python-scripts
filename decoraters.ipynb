# %% [markdown]
# A decorator is a way of extending a function, wiwth an @ operator. This can be removed when if it is no longer needed.
#
#     @some_decorator
#     def simple_func()
#         #do something
#         return something

# %%
def func():
    return 1

# %%
func()
# Out:
# 1

# %%
func
# Out:
# <function __main__.func()>

# %%
def hello():
    return "Hello!"

# %%
greet = hello

# %%
greet()
# Out:
# 'Hello!'

# %%
hello()
# Out:
# 'Hello!'

# %%
del hello

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10412/2674044599.py in <module>
# ----> 1 hello()
#
# NameError: name 'hello' is not defined

# %%
greet()
# Out:
# 'Hello!'

# %% [markdown]
# greet completely copies the hello function, and isn't just dependent on it

# %%
def hello(name="Jose"):
    print("The hello() function has  been executed!")
    
    def greet():
        return "\t This is the greet function inside hello"
    
    def welcome():
        return "\t This is welcome() inside hello"
    
    print(greet())
    print(welcome())

# %%
hello()
# Out:
# The hello() function has  been executed!
# 	 This is the greet function inside hello
# 	 This is welcome() inside hello

# %%
print("This is the end of the hello function!")
# Out:
# This is the end of the hello function!

# %%
welcome()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10412/241228648.py in <module>
# ----> 1 welcome()
#
# NameError: name 'welcome' is not defined

# %%
def hello(name="Jose"):
    print("The hello() function has  been executed!")
    
    def greet():
        return "\t This is the greet function inside hello"
    
    def welcome():
        return "\t This is welcome() inside hello"
    
    print("I am going to return a function")
    
    if name == "Jose":
        return greet
    else:
        return welcome

# %%
my_new_func = hello("Jose")
# Out:
# The hello() function has  been executed!
# I am going to return a function

# %%
my_new_func
# Out:
# <function __main__.hello.<locals>.greet()>

# %%
print(my_new_func())
# Out:
# 	 This is the greet function inside hello

# %%
def cool():
    
    def super_cool():
        return "I am very cool"
    
    return super_cool

# %%
some_func = cool()

# %%
some_func
# Out:
# <function __main__.cool.<locals>.super_cool()>

# %%
some_func()
# Out:
# 'I am very cool'

# %%
def hello():
    return "Hi Jose!"

# %%
def other(some_def_func):
    print("Other code runs here")
    print(some_def_func())

# %%
hello
# Out:
# <function __main__.hello()>

# %%
hello()
# Out:
# 'Hi Jose!'

# %% [markdown]
# the raw function of hello will be executed in other

# %%
other(hello)
# Out:
# Other code runs here
# Hi Jose!

# %%
def new_decorator(original_func):
    
    def wrap_func():
        
        print("Some extra code, before the original function")
        
        original_func()
        
        print('Some extra code, after the original function')
        
        return wrap_func

# %% [markdown]
# takes in the original function, passes some code then passes the original function then passes more code.
#
# original function has been "wrapped" up with the wrap_func

# %%
def func_needs_decorator():
    print("I want to be decorated!!")

# %%
func_needs_decorator()
# Out:
# I want to be decorated!!

# %%
decorated_func = new_decorator(func_needs_decorator)

# %%
decorated_func()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10412/2503767838.py in <module>
# ----> 1 decorated_func()
#
# TypeError: 'NoneType' object is not callable

# %%
def new_decorator(func):

    def wrap_func():
        print("Code would be here, before executing the func")

        func()

        print("Code here will execute after the func()")

    return wrap_func

def func_needs_decorator():
    print("This function is in need of a Decorator")

# %%
func_needs_decorator()
# Out:
# This function is in need of a Decorator

# %%
# Reassign func_needs_decorator
func_needs_decorator = new_decorator(func_needs_decorator)

# %%
func_needs_decorator()
# Out:
# Code would be here, before executing the func
# This function is in need of a Decorator
# Code here will execute after the func()

# %%
@new_decorator
def func_needs_decorator():
    print("I want to be decorated")

# %%
func_needs_decorator()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10412/523226480.py in <module>
# ----> 1 func_needs_decorator()
#
# TypeError: 'NoneType' object is not callable
