# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict[key1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14752/3316764407.py in <module>
# ----> 1 my_dict[key1]
#
# NameError: name 'key1' is not defined

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple':2.99,'oranges':1.99,'milk':5.80}

# %%
prices_lookup['apple']
# Out:
# 2.99

# %%
d = {'k1':123,'k2':[0,1,2],'k3':{'insideKey':100}}

# %%
d['k2']
# Out:
# [0, 1, 2]

# %%
d['k3']
# Out:
# {'insideKey': 100}

# %%
d['k3']['insideKey']
# Out:
# 100

# %%
d['k2'][2]
# Out:
# 2

# %%
d = {'key1':['a','b','c']}

# %%
d
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
myList = d['key1']

# %%
myList
# Out:
# ['a', 'b', 'c']

# %%
letter = myList[2]

# %%
letter.isupper()
# Out:
# False

# %%
letter.upper()
# Out:
# 'C'

# %%
# or

# %%
d['key1'][2].upper()
# Out:
# 'C'

# %%
d = {'k1':100,'k2': 200}

# %%
d['k3'] = 300

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d['k1']
# Out:
# 100

# %%
d['k1'] = 'New value'

# %%
d['k1']
# Out:
# 'New value'

# %%
d['k1'] + 'Another new value'
# Out:
# 'New valueAnother new value'

# %%
d['k1']
# Out:
# 'New value'

# %%
d['k1' + 'anotherNew']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14752/1984198084.py in <module>
# ----> 1 d['k1' + 'anotherNew']
#
# KeyError: 'k1anotherNew'

# %%
d['k1'] = d['k1'] + 'anotherNew'

# %%
d['k1']
# Out:
# 'New valueanotherNew'

# %%
d = {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items()
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 300)])

# %%
d.keys().upper
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14752/3186841565.py in <module>
# ----> 1 d.keys().upper
#
# AttributeError: 'dict_keys' object has no attribute 'upper'
