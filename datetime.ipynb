# %%
import datetime

# %%
mytime = datetime.time(2,20)

# %%
mytime.minute
# Out:
# 20

# %%
mytime.hour
# Out:
# 2

# %%
print(mytime)
# Out:
# 02:20:00

# %%
mytime = datetime.time(2)

# %%
print(mytime)
# Out:
# 02:00:00

# %%
mytime.microsecond
# Out:
# 0

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2022-05-10

# %%
today.year
# Out:
# 2022

# %%
today.month
# Out:
# 5

# %%
today.day
# Out:
# 10

# %%
today.ctime()
# Out:
# 'Tue May 10 00:00:00 2022'

# %% [markdown]
# might need above for a particular database time

# %%
from datetime import datetime

# %%
mydatetime = datetime(2021,10,3,14,20)

# %%
print(mydatetime)
# Out:
# 2021-10-03 14:20:00

# %%
mydatetime.replace(year=2022)
# Out:
# datetime.datetime(2022, 10, 3, 14, 20)

# %%
mydatetime = mydatetime.replace(year=2022)

# %%
print(mydatetime)
# Out:
# 2022-10-03 14:20:00

# %%
# DATE

# %%
from datetime import date

# %%
date1 = date(2021,11,3)
date2 = date(2020,11,3)

# %%
date1 - date2
# Out:
# datetime.timedelta(days=365)

# %%
result = date1 - date2

# %%
type(result)
# Out:
# datetime.timedelta

# %%
result.days
# Out:
# 365

# %%
datetime1 = datetime(2022,11,3,22,0)
datetime2 = datetime(2021,11,3,12,0)

# %%
datetime1 - datetime2
# Out:
# datetime.timedelta(days=365, seconds=36000)

# %%
36000/60 #minutes
# Out:
# 600.0

# %%
3600/60 #hours
# Out:
# 60.0

# %%
mydiff = datetime1 - datetime2

# %%
mydiff.seconds
# Out:
# 36000

# %%
mydiff.total_seconds()
# Out:
# 31572000.0

# %% [markdown]
# seconds portion includes the whole format in seconds

# %%
import datetime
from datetime import datetime
from datetime import time

# %%
timetest = time(4,20,1)

# Let's show the different components
print(timetest)
# Out:
# 04:20:01

# %% [markdown]
# print('hour  :', t.hour)
# print('minute:', t.minute)
# print('second:', t.second)
# print('microsecond:', t.microsecond)
# print('tzinfo:', t.tzinfo)

# %%
print("Hour:", timetest.hour)
print("minute:",timetest.minute)
# Out:
# Hour: 4
# minute: 20

# %%
print('Earliest  :', time.min)
print('Latest    :', time.max)
print('Resolution:', time.resolution)
# Out:
# Earliest  : 00:00:00
# Latest    : 23:59:59.999999
# Resolution: 0:00:00.000001

# %%
today = date.today()
print(today)
print('ctime:', today.ctime())
print('tuple:', today.timetuple())
print('ordinal:', today.toordinal())
print('Year :', today.year)
print('Month:', today.month)
print('Day  :', today.day)
# Out:
# 2022-05-10
# ctime: Tue May 10 00:00:00 2022
# tuple: time.struct_time(tm_year=2022, tm_mon=5, tm_mday=10, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=130, tm_isdst=-1)
# ordinal: 738285
# Year : 2022
# Month: 5
# Day  : 10

# %%
print("Earliest: ", date.min)
print("Latest: ", date.max)
print("Resolution",date.resolution)
# Out:
# Earliest:  0001-01-01
# Latest:  9999-12-31
# Resolution 1 day, 0:00:00
