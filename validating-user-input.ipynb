# %%
def user_choice():
    choice = input("Please enter a number (0-10): ")
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): 9
# 9

# %%
user_choice()
# Out:
# Please enter a number (0-10): Nine
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4744/2296594588.py in <module>
# ----> 1 user_choice()
#
# ~\AppData\Local\Temp/ipykernel_4744/224083779.py in user_choice()
#       1 def user_choice():
#       2     choice = input("Please enter a number (0-10): ")
# ----> 3     return int(choice)
#
# ValueError: invalid literal for int() with base 10: 'Nine'

# %%
user_choice()
# Out:
# Please enter a number (0-10): 21
# 21

# %%
some_value = '100'

# %%
some_value.isdigit()
# Out:
# True

# %%
int(some_value)
# Out:
# 100

# %%
def user_choice():
    choice =  'Wrong'
    #while choice is not digit 
    while choice.isdigit() == False:
        #keep asking for input
        choice = input("Please enter a number (0-10): ")
        #after user choice
        if choice.isdigit() == False:
            print("Sorry, that is not a digit!")
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): sasg
# Sorry, that is not a digit!
# Please enter a number (0-10): two
# Sorry, that is not a digit!
# Please enter a number (0-10): 2
# 2

# %%
result = "Wrong value"

# %%
acceptable_values = [0,1,2]

# %%
result in acceptable_values
# Out:
# False

# %%
result not in acceptable_values
# Out:
# True

# %%
def user_choice():
    #variables
    
    #initial 
    choice =  'Wrong'
    acceptable_range = range(0,10)
    within_range = False
    
    #two conditions to check
    # digit or within range==False
    #while choice is not digit 
    while choice.isdigit() == False or within_range==False:
        choice = input("Please enter a number (0-10): ")
        # digit check
        if choice.isdigit() == False:
            print("Sorry, that is not a digit!")
        #range check
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range = True
            else:
                print("Sorry, you are out of acceptable range (0-10)")
                within_range = False
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10): two
# Sorry, that is not a digit!
# Please enter a number (0-10): 100
# Sorry, you are out of acceptable range (0-10)
# Please enter a number (0-10): 4
# 4
