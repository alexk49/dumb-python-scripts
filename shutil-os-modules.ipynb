# %%
pwd
# Out:
# 'C:\\Users\\Alex\\MyPythonStuff\\modules'

# %%
f = open('practice.txt','w+')
f.write("This is a test string")
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Alex\\MyPythonStuff\\modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Collections module.ipynb',
#  'practice.txt',
#  'Shutil (show utilities) and os module.ipynb']

# %%
os.listdir("C:\\Users")
# Out:
# ['Alex', 'All Users', 'Default', 'Default User', 'desktop.ini', 'Public']

# %%
import shutil

# %%
shutil.move("practice.txt","C:\\Users\\Alex\\MyPythonStuff")
# Out:
# 'C:\\Users\\Alex\\MyPythonStuff\\practice.txt'

# %%
os.listdir("C:\\Users\\Alex\\MyPythonStuff\\")
# Out:
# ['.ipynb_checkpoints',
#  '2 python statements',
#  'Complete-Python-3-Bootcamp-master',
#  'decorators',
#  'error handling',
#  'generators',
#  'methods',
#  'milestone project',
#  'milestone project 2',
#  'modules',
#  'object orientated programming',
#  'practice.txt',
#  'Python Object and Data Structure Basics',
#  'test.py']

# %%
import send2trash

# %% [markdown]
# if you remove something with shutil.rmtree(path) it can be v.difficult to recover, this is why you should use send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Collections module.ipynb',
#  'Shutil (shell utilities) and os module.ipynb']

# %%
shutil.move('C:\\Users\\Alex\\MyPythonStuff\\practice.txt',os.getcwd())
# Out:
# 'C:\\Users\\Alex\\MyPythonStuff\\modules\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Collections module.ipynb',
#  'practice.txt',
#  'Shutil (shell utilities) and os module.ipynb']

# %%
send2trash.send2trash("practice.txt")

# %%
filepath = r"C:\Users\Alex\MyPythonStuff\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level"
for folder,sub_folders,files in os.walk(filepath):

    print(f"Currently looking at {folder}")
    print("\n")
    print("The sub folders are: ")
    for sub_fold in sub_folders:
        print(f"\t Subfolder: {sub_fold}")
        
    print('\n')
    print("the files are: ")
    for f in files:
        print(f"\t File: {f}")
    print('\n')
# Out:
# Currently looking at C:\Users\Alex\MyPythonStuff\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level
#
#
# The sub folders are:
# 	 Subfolder: Mid-Example-One
#
#
# the files are:
# 	 File: Mid-Example.txt
#
#
# Currently looking at C:\Users\Alex\MyPythonStuff\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One
#
#
# The sub folders are:
# 	 Subfolder: Bottom-Level-One
# 	 Subfolder: Bottom-Level-Two
#
#
# the files are:
# 	 File: Mid-Level-Doc.txt
#
#
# Currently looking at C:\Users\Alex\MyPythonStuff\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One\Bottom-Level-One
#
#
# The sub folders are:
#
#
# the files are:
# 	 File: One_Text.txt
#
#
# Currently looking at C:\Users\Alex\MyPythonStuff\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One\Bottom-Level-Two
#
#
# The sub folders are:
#
#
# the files are:
# ...

# %% [markdown]
# os walk makes a tree, and looks at everything in the file path that you give it.
#
# so you can then add logic to it, say if statement to look for .txt
#
# look for directories in directories
