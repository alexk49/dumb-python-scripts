# %%
# Card class
# Suit of card 
# rank of card
# value of card, as integer 

# deck class 

# player who can hold cards

# the defined class can reference either a global variable (eg values) or an imported library
#eg random

# %%
import random 

suits = ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values = {'Two':2, 'Three':3, 'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':11,'Queen':12,'King':13,'Ace':14}

# %%
#values variable has to exactly match up to rank - so you have to use the capitals

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        # str returns string version of self, when printed
        # return rank of suit, eg. queen of hearts
        return self.rank + " of " + self.suit

# %% [markdown]
# Deck class
# - instantiate a new deck
#     - create all 52 card objects
#     - hold as a list of card objects
# - Shuffle a deck through a method call
#     - random library shuffle() function
# - deal cards from the deck object
#     - pop method from cards list
#
# The deck class will have a list of card objects
#
# this means the deck class will return card class object instances, not just normal python data types
#
# instead of holding integers or strings, the class will hold a different created class / object

# %%
class Deck:
    
    def __init__(self):
        # starts as an empty list with no input from the user
        self.all_cards = []
        # create all 52 unique cards
        # for every suit you need to create a rank
        for suit in suits:
            for rank in ranks:
                # Create the card object
                created_card = Card(suit,rank)
                
                self.all_cards.append(created_card)
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %% [markdown]
# `Player class
#     this class will be used to hold a players current list of cards
#     a player should be able to add or remove cards from their hand (list of Card objects)
#
#    We will want the player to be able to add a single card or multiple cards to their list
#
# will need to translate a deck/hand of cards with a top and bottom to a python list
#     -you draw cards from the top of the deck but will add cards you win to the bottom
#     players play from top of hnd - cards.pop(0) but add to cards.append()
#     adding multiples cards can use .extend() method, which takes a list and merges with an existing list - this adds to the list whereas append with multiple will nest the list
#
# player class will have a self.all_cards list

# %%
class Player:
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        #if multiple card objects, type list
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards.'

# %%
class Deck:
    
    def __init__(self):
        # starts as an empty list with no input from the user
        self.all_cards = []
        # create all 52 unique cards
        # for every suit you need to create a rank
        for suit in suits:
            for rank in ranks:
                # Create the card object
                created_card = Card(suit,rank)
                
                self.all_cards.append(created_card)
                
    def shuffle(self):
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        return self.all_cards.pop()

# %% [markdown]
# Game logic - you need to think about the game logic simultaneously as designing the classes and functions
#
# player 1, player 2
#
# new deck
# shufflee
#
# split deck between player one and two
#
# after each round, you will need to check if someone has lost:
# check for 0 cards
#
# game_on = True - while game_on:
#
# each player draws a card
#
# compare the cards against one another-
#
# if instance of war, players need additional 3 cards.
# Need a While at_war game loop, you can have mulitple war within war situations
#
# do comparison over and over
#
# winner gets cards added to bottom of deck
#
# check if someone has lost, if so game_on = False
#
# declare a winner

# %%
# game setup

player_one = Player("One")
player_two = Player("Two")

new_deck = Deck()
new_deck.shuffle()

#deal one card to each player 26 times
# meaning 52 cards split
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
game_on = True

# %% [markdown]
# if One > Two
#     Add cards to one
#     at_war = False
#
# elif:
#     One < Two
#     add cards to two
#     at_war = False
#
# else:
#     at_war = True
#     check if players have enough cards
#     draw additional cards
#     re-loop, to the start to loop - as it then checks the first card

# %%
round_num = 0

while game_on:
    #add one to round num counter
    round_num += 1
    print(f"Round {round_num}")
    
    # check victory conditions
    if len(player_one.all_cards) == 0:
        print("Player One, out of cards. Player two wins!")
        game_on = False
        break
    
    if len(player_two.all_cards) == 0:
        print("Player Two, out of cards. Player one wins!")
        game_on = False
        break
    
    #start new round
    
    # current card in play    
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    #comparison p1>p2,p1<p2,p1==p2
    #players need 5 additional cards if tie
    #player loses if they don't have at least 5 cards
    
    
    
    
    
    
# while game_on 

    # while at_war
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10504/3466880064.py in <module>
#       1 round_num = 0
#       2
# ----> 3 while game_on:
#       4     #add one to round num counter
#       5     round_num += 1
#
# NameError: name 'game_on' is not defined

# %%
print(new_player)
# Out:
# Player Jose has 0 cards.

# %%
new_deck = Deck()

# %%
new_deck.shuffle()

# %%
mycard = new_deck.deal_one()

# %%
print(mycard)
# Out:
# Eight of Diamonds

# %%
len(new_deck.all_cards)
# Out:
# 51

# %%
new_player.add_cards(mycard)

# %%
print(new_player)
# Out:
# Player Jose has 1 cards.

# %%
print(new_player.all_cards[0])
# Out:
# Eight of Spades

# %%
new_player.add_cards([mycard,mycard,mycard])

# %%
print(new_player)
# Out:
# Player Jose has 4 cards.

# %%
new_player.remove_one()

# %%
print(new_player)
# Out:
# Player Jose has 3 cards.

# %%
new_deck.all_cards

# %%
new_deck.all_cards[0]

# %%
first_card = new_deck.all_cards[0]

# %%
print(first_card)
# Out:
# Two of Hearts

# %%
new_deck.shuffle()

# %%
print(new_deck.all_cards[-1])
# Out:
# Four of Spades

# %%
three_of_clubs = Card("Clubs","Three")

# %%
three_of_clubs.rank
# Out:
# 'Three'

# %%
two_hearts = Card("Hearts","Two")

# %%
two_hearts

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %%
two_hearts.suit
# Out:
# 'Hearts'

# %%
two_hearts.rank
# Out:
# 'Two'

# %%
values[two_hearts.rank]
# Out:
# 2

# %%
two_hearts.value < three_of_clubs.value
# Out:
# True

# %% [markdown]
# ^ you have to compare the value as otherwise python can't compare the strings, it needs the integer

# %%
two_hearts.value == three_of_clubs.value
# Out:
# False
