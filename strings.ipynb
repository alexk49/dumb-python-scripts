# %%
'hello'
# Out:
# 'hello'

# %%
'world'
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
"I'm going on a run"
# Out:
# "I'm going on a run"

# %%
print("hello")
# Out:
# hello

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
print('hello \nworld')
# Out:
# hello
# world

# %%
len('hello')
# Out:
# 5

# %%
len("I am")
# Out:
# 4

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring[-3]
# Out:
# 'r'

# %%
mystring = 'abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[0:2]
# Out:
# 'ab'

# %%
mystring[0:3]
# Out:
# 'abc'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[3:-2]
# Out:
# 'defghi'

# %%
mystring[3:8]
# Out:
# 'defgh'

# %%
mystring[3:9]
# Out:
# 'defghi'

# %%
mystring[::]
# Out:
# 'abcdefghijk'

# %%
mystring[::3]
# Out:
# 'adgj'

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %%
mystring[::-1]
# Out:
# 'kjihgfedcba'

# %%
name = "Sam"

# %%
# name[0] = 'P'

# %%
'P' + name[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12568/1505070028.py in <module>
# ----> 1 'P' + name[1:]
#
# NameError: name 'name' is not defined

# %%
name[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12568/1820945629.py in <module>
# ----> 1 name[1:]
#
# NameError: name 'name' is not defined

# %%
name = "Sam"

# %%
"P" + name[1:]
# Out:
# 'Pam'

# %%
last_letters = name[1:]

# %%
'p' + last_letters
# Out:
# 'pam'

# %%
x = 'Hello World'

# %%
x + ' it is beautiful outside!'
# Out:
# 'Hello World it is beautiful outside!'

# %%
x = x + "it is beautiful outside"

# %%
x
# Out:
# 'Hello Worldit is beautiful outside'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
'2' + '3'
# Out:
# '23'

# %%
int('2', '3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12568/3627389852.py in <module>
# ----> 1 int('2', '3')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
int(str('2', '3'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12568/3210971817.py in <module>
# ----> 1 int(str('2', '3'))
#
# TypeError: decoding str is not supported

# %%
x = 'Hello World'

# %%
x.upper
# Out:
# <function str.upper()>

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.lower
# Out:
# <function str.lower()>

# %%
x.split
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
x.split('i')
# Out:
# ['Hello World']

# %%
x = 'Hi this is a string'

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a str', 'ng']

# %%
#

# %% [markdown]
# markdown test
